# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values
# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML # tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize
import folium # plotting library

# %%
CLIENT_ID = '' # your Foursquare ID
CLIENT_SECRET = '' # your Foursquare Secret
ACCESS_TOKEN = '' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: WQLGO4YEN02SDJPXNV2IW4V5PODGQQ55EAHUQHNFSEA2TJDU
# CLIENT_SECRET:S50F25SRFTOAMLZ0JENOG2PTGFW1MWWWYH335MC22L1UFJXC

# %%
longitude = 120.301956
latitude = 22.631388
print(latitude, longitude)
# Out:
# 22.631388 120.301956

# %%
search_query = 'Night Market'
radius = 10000
print(search_query + ' .... OK!')
# Out:
# Night Market .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=WQLGO4YEN02SDJPXNV2IW4V5PODGQQ55EAHUQHNFSEA2TJDU&client_secret=S50F25SRFTOAMLZ0JENOG2PTGFW1MWWWYH335MC22L1UFJXC&ll=22.631388,120.301956&oauth_token=CBTIB2RRVBUSKR2S4ZVUHMCZ3VDJ4HGZRXTPXBJQIZ4YYSWT&v=20180604&query=Night Market&radius=10000&limit=100'

# %%
results = requests.get(url).json()
venues = results['response']['venues']
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# <ipython-input-8-bc0f259b5133>:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dataframe = json_normalize(venues)
#                          id                            name  \
# 0  4d90ab691a6bba7a9b026c70      Nanhua Night Market (南華夜市)
# 1  4d5d28051ef2f04d196bfccd     忠孝夜市 Zhongsiao Night Market
# 2  4d6e81a39af52c0f3f0293dd  興中觀光夜市 Sing Jhong Night Market
# 3  4d18a1446c8b548142a2f2cc       星期一夜市 Monday Night Market
# 4  4b9a255cf964a5202da135e3      光華夜市 Guanghua Night Market
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '53e510b7498ebcb1801b55d4', 'name': 'N...  v-1624823218    False
# 1  [{'id': '53e510b7498ebcb1801b55d4', 'name': 'N...  v-1624823218    False
# 2  [{'id': '53e510b7498ebcb1801b55d4', 'name': 'N...  v-1624823218    False
# 3  [{'id': '4bf58dd8d48988d120951735', 'name': 'F...  v-1624823218    False
# 4  [{'id': '53e510b7498ebcb1801b55d4', 'name': 'N...  v-1624823218    False
#
#     location.address   location.crossStreet  location.lat  location.lng  \
# 0      高雄市新興區南華一路40號                   新興市場     22.629036    120.302810
# 1  Zhongsiao 2nd Rd.  btw Qingnian & Lingya     22.621223    120.307622
# 2            苓雅區文橫二路                    三多路     22.614773    120.306880
# 3      高雄市苓雅區廣東一街97巷                    NaN     22.621032    120.320212
# 4         高雄市苓雅區光華二路   btw Sandou & guangxi     22.617095    120.318242
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 22.629036, 'lng':...                276
# 1  [{'label': 'display', 'lat': 22.62122295591197...               1272
# 2  [{'label': 'display', 'lat': 22.61477347737183...               1917
# 3  [{'label': 'display', 'lat': 22.621032, 'lng':...               2201
# 4  [{'label': 'display', 'lat': 22.61709490241331...               2309
#
#   location.postalCode location.cc location.city location.country  \
# 0                 800          TW           高雄市               臺灣
# 1                 NaN          TW           高雄市               臺灣
# 2                 802          TW           高雄市               臺灣
# 3                 NaN          TW           高雄市               臺灣
# 4                 NaN          TW           高雄市               臺灣
#
#                           location.formattedAddress venuePage.id  \
# 0                 [高雄市新興區南華一路40號 (新興市場), 高雄市,  800]          NaN
# 1  [Zhongsiao 2nd Rd. (btw Qingnian & Lingya), 高雄市]          NaN
# 2                        [苓雅區文橫二路 (三多路), 高雄市,  802]          NaN
# 3                              [高雄市苓雅區廣東一街97巷, 高雄市]          NaN
# 4          [高雄市苓雅區光華二路 (btw Sandou & guangxi), 高雄市]          NaN
#
#   location.neighborhood
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
# Keep columns we need, and delete the row which is not night market.
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']  
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]
dataframe_filtered = dataframe_filtered[dataframe_filtered["categories"] == "Night Market"]
dataframe_filtered
# Out:
#                                         name    categories            address  \
# 0                 Nanhua Night Market (南華夜市)  Night Market      高雄市新興區南華一路40號
# 1                忠孝夜市 Zhongsiao Night Market  Night Market  Zhongsiao 2nd Rd.
# 2             興中觀光夜市 Sing Jhong Night Market  Night Market            苓雅區文橫二路
# 4                 光華夜市 Guanghua Night Market  Night Market         高雄市苓雅區光華二路
# 5               金鑽觀光夜市 Jin-Zuan Night Market  Night Market        前鎮區凱旋四路788號
# 8                 Liouhe Night Market (六合夜市)  Night Market               六合二路
# 10                                      吉林夜市  Night Market                吉林街
# 14               La Rue Market by Love River  Night Market                NaN
# 16                                    勞工公園夜市  Night Market             前鎮區一德路
# 17                                      自強夜市  Night Market               自強三路
# 24                                    旗津國小夜市  Night Market                復興巷
# 35                Pier-2 Night Market (駁二夜市)  Night Market            建國四路71號
# 40                                      瑞北夜市  Night Market                瑞北路
# 42  Kaixuan Qingnian Night Market (凱旋青年觀光夜市)  Night Market           凱旋四路758號
# 43              Rueifeng Night Market (瑞豐夜市)  Night Market           裕誠路1128號
# 45                                  凱旋國際觀光夜市  Night Market           凱旋四路758號
#
#               crossStreet        lat         lng  \
# 0                    新興市場  22.629036  120.302810
# 1   btw Qingnian & Lingya  22.621223  120.307622
# 2                     三多路  22.614773  120.306880
# 4    btw Sandou & guangxi  22.617095  120.318242
# 5                     NaN  22.599798  120.320777
# 8                     NaN  22.632438  120.300083
# 10                    NaN  22.644094  120.306300
# 14                    NaN  22.622690  120.289186
# 16                    NaN  22.608355  120.309942
# 17          Lingya 2nd Rd  22.617052  120.298500
# 24                    NaN  22.606761  120.271859
# 35                    NaN  22.622526  120.278661
# 40                    NaN  22.609068  120.330670
# 42                    NaN  22.598960  120.319790
# 43                   南屏路口  22.665931  120.299845
# 45                    NaN  22.599017  120.319863
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 22.629036, 'lng':...       276        800
# 1   [{'label': 'display', 'lat': 22.62122295591197...      1272        NaN
# 2   [{'label': 'display', 'lat': 22.61477347737183...      1917        802
# 4   [{'label': 'display', 'lat': 22.61709490241331...      2309        NaN
# 5   [{'label': 'display', 'lat': 22.59979817512787...      4013        806
# 8   [{'label': 'display', 'lat': 22.63243761586824...       225        NaN
# 10  [{'label': 'display', 'lat': 22.64409416767027...      1483        807
# 14  [{'label': 'display', 'lat': 22.62269, 'lng': ...      1630      80341
# 16  [{'label': 'display', 'lat': 22.60835517368099...      2692        806
# 17  [{'label': 'display', 'lat': 22.617052, 'lng':...      1634        802
# 24  [{'label': 'display', 'lat': 22.606761, 'lng':...      4132        805
# 35  [{'label': 'display', 'lat': 22.62252611925212...      2588        803
# 40  [{'label': 'display', 'lat': 22.609068, 'lng':...      3857        806
# 42  [{'label': 'display', 'lat': 22.59896, 'lng': ...      4048        806
# 43  [{'label': 'display', 'lat': 22.66593113167786...      3851        813
# 45  [{'label': 'display', 'lat': 22.5990168291308,...      4046        NaN
#
#     cc               city country  \
# 0   TW                高雄市      臺灣
# 1   TW                高雄市      臺灣
# 2   TW                高雄市      臺灣
# 4   TW                高雄市      臺灣
# 5   TW                高雄市      臺灣
# 8   TW                高雄市      臺灣
# 10  TW                三民區      臺灣
# 14  TW                 鹽埕      臺灣
# 16  TW                高雄市      臺灣
# 17  TW                苓雅區      臺灣
# 24  TW                旗津區      臺灣
# 35  TW                鹽埕區      臺灣
# 40  TW  Qianzhen District      臺灣
# 42  TW                前鎮區      臺灣
# 43  TW                左營區      臺灣
# 45  TW                前鎮區      臺灣
#
#                                     formattedAddress neighborhood  \
# 0                  [高雄市新興區南華一路40號 (新興市場), 高雄市,  800]          NaN
# 1   [Zhongsiao 2nd Rd. (btw Qingnian & Lingya), 高雄市]          NaN
# 2                         [苓雅區文橫二路 (三多路), 高雄市,  802]          NaN
# 4           [高雄市苓雅區光華二路 (btw Sandou & guangxi), 高雄市]          NaN
# 5                           [前鎮區凱旋四路788號, 高雄市,  806]          NaN
# 8                                        [六合二路, 高雄市]          NaN
# 10                                  [吉林街, 三民區,  807]          NaN
# 14                                      [鹽埕,  80341]          NaN
# 16                               [前鎮區一德路, 高雄市,  806]          NaN
# 17                 [自強三路 (Lingya 2nd Rd), 苓雅區,  802]          NaN
# 24                                  [復興巷, 旗津區,  805]          NaN
# 35                              [建國四路71號, 鹽埕區,  803]          NaN
# 40                    [瑞北路, Qianzhen District,  806]          NaN
# 42                             [凱旋四路758號, 前鎮區,  806]          NaN
# 43                      [裕誠路1128號 (南屏路口), 左營區,  813]      Zuoying
# 45                                   [凱旋四路758號, 前鎮區]          NaN
#
#                           id
# 0   4d90ab691a6bba7a9b026c70
# 1   4d5d28051ef2f04d196bfccd
# 2   4d6e81a39af52c0f3f0293dd
# 4   4b9a255cf964a5202da135e3
# 5   52c79fed11d217c0b28a5d9f
# 8   4b63112cf964a520bc602ae3
# 10  4caf2bed1168a093bdf81f23
# 14  5ef89070afc30000086503a0
# 16  4eca32149adf9c7bf628bf88
# 17  4d14cfc3e190721ef9640a21
# 24  55685d72498e635cb82e88cb
# 35  53088ebd498e40cc25a0eb75
# 40  4d970434942ba093a401618c
# 42  5b00143da0215b002c262d5b
# 43  4bfe429af7c82d7fca4e8f04
# 45  51f928a1498e00e66f88d4b8

# %% [markdown]
# Visualization time!

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13)
# add a red circle marker to represent the Formosa Boulevard
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Formosa Boulevard',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the night markets as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_622c4675e99d4592a98322bfa983901c%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_622c4675e99d4592a98322bfa983901c%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_622c4675e99d4592a98322bfa983901c%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_622c4675e99d4592a98322bfa983901c%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B22.631388%2C120.301956%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2013%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%20% ...
